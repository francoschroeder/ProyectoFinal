# %% [markdown]
# ###  Import libraries

# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np
from tensorflow import keras
from datetime import datetime
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

import time

import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %% [markdown]
# ### Hiperparámetros

# %%
csv_path          = "regina.csv"
dropped_features  = ['Hi Temp', 'Low Temp', 'Wind Chill', 'Heat Index', 'THSW Index', 'THW Index', 'Wind Run', 'Solar Energy', 'Hi Solar Rad.', 'In Heat', 'ISS Recept', 'Arc. Int']

train_perc = .8
val_perc   = .1

sequence_length = 90
offset          = 0
sampling_rate   = 1
length          = 6 #horas
min_temp        = 0.5
batch_size      = 256

learning_rate   = 0.001
epochs          = 1

# %% [markdown]
# ### Read CSV

# %%
dateparse = lambda x: datetime.strptime(x, '%d.%m.%y %H:%M')

wind_dic = {'---' : 0,
            'E': 1,
            'W': 2,
            'N': 3,
            'S': 4,
            'NE': 5,
            'SE': 6,
            'NW': 7,
            'SW': 8,
            'ENE': 9,
            'NNE': 10,
            'WNW': 11,
            'NNW': 12,
            'ESE': 13,
            'SSE': 14,
            'WSW': 15,
            'SSW': 16}

data = pd.read_csv(csv_path, parse_dates=['Date Time'], date_parser=dateparse, na_values=['---', '------'], converters={'Wind Dir': lambda x: wind_dic[x], 'Hi Dir': lambda x: wind_dic[x]}, index_col=0)

# %% [markdown]
# ### Agregamos los datos que faltan

# %%
data['Temp Out'] = data['Temp Out'].apply(lambda x: x-2)
data['Temp Out'] = data['Temp Out'].apply(lambda x: np.nan if x <= -10 else x)

data = data.resample('10min', origin='start').mean()

data['Wind Dir'] = data['Wind Dir'].replace(np.nan, 0)
data['Hi Dir'] = data['Hi Dir'].replace(np.nan, 0)

data = data.interpolate()

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 627179 entries, 2010-01-28 14:20:00 to 2022-01-01 00:00:00
# Freq: 10T
# Data columns (total 31 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Temp Out       627179 non-null  float64
#  1   Hi Temp        627179 non-null  float64
#  2   Low Temp       627179 non-null  float64
#  3   Out Hum        627179 non-null  float64
#  4   Dew Pt.        627179 non-null  float64
#  5   Wind Speed     627179 non-null  float64
#  6   Wind Dir       627179 non-null  float64
#  7   Wind Run       627179 non-null  float64
#  8   Hi Speed       627179 non-null  float64
#  9   Hi Dir         627179 non-null  float64
#  10  Wind Chill     627179 non-null  float64
#  11  Heat Index     627179 non-null  float64
#  12  THW Index      627179 non-null  float64
#  13  THSW Index     622656 non-null  float64
#  14  Bar            627179 non-null  float64
#  15  Rain           627179 non-null  float64
#  16  Rain Rate      627179 non-null  float64
#  17  Solar Rad.     627179 non-null  float64
#  18  Solar Energy   627179 non-null  float64
#  19  Hi Solar Rad.  627179 non-null  float64
#  20  Heat D-D       627179 non-null  float64
#  21  Cool D-D       627179 non-null  float64
#  22  In Temp        627179 non-null  float64
#  23  In Hum         627179 non-null  float64
#  24  In Dew         627179 non-null  float64
#  25  In Heat        627179 non-null  float64
#  26  ET             627179 non-null  float64
#  27  Wind Samp      627179 non-null  float64
#  28  Wind Tx        627179 non-null  float64
#  29  ISS Recept     627179 non-null  float64
#  30  Arc. Int       627179 non-null  float64
# dtypes: float64(31)
# memory usage: 153.1 MB

# %% [markdown]
# ### Convertimos estampillas de tiempo todo a segundos

# %%
timestamp_s = data.index
timestamp_s = timestamp_s.map(pd.Timestamp.timestamp)

day = 24*60*60
year = 365.2425 * day

data['Day sin'] = np.sin(timestamp_s * (2 * np.pi / day))
data['Day cos'] = np.cos(timestamp_s * (2 * np.pi / day))
data['Year sin'] = np.sin(timestamp_s * (2 * np.pi / year))
data['Year cos'] = np.cos(timestamp_s * (2 * np.pi / year))

# %% [markdown]
# ## Correlación de los datos

# %%
data.corr()
# Out:
#                Temp Out   Hi Temp  Low Temp   Out Hum   Dew Pt.  Wind Speed  \
# Temp Out       1.000000  0.948982  0.946571 -0.641234  0.630166    0.212185
# Hi Temp        0.948982  1.000000  0.995834 -0.618553  0.637439    0.203664
# Low Temp       0.946571  0.995834  1.000000 -0.616361  0.635813    0.206264
# Out Hum       -0.641234 -0.618553 -0.616361  1.000000  0.141228   -0.401745
# Dew Pt.        0.630166  0.637439  0.635813  0.141228  1.000000   -0.120652
# Wind Speed     0.212185  0.203664  0.206264 -0.401745 -0.120652    1.000000
# Wind Dir       0.244404  0.231939  0.233991 -0.305096  0.025540    0.318082
# Wind Run       0.212836  0.204288  0.206885 -0.402432 -0.120465    0.999991
# Hi Speed       0.322088  0.309187  0.311684 -0.504793 -0.085600    0.918865
# Hi Dir         0.246937  0.234780  0.236768 -0.318324  0.014211    0.335477
# Wind Chill     0.943194  0.998144  0.995825 -0.606531  0.643162    0.168176
# Heat Index     0.981536  0.966594  0.964463 -0.581647  0.705630    0.179286
# THW Index      0.977347  0.965334  0.963167 -0.571074  0.712655    0.140919
# THSW Index     0.257340  0.248854  0.248163 -0.199112  0.135169    0.157370
# Bar           -0.600088 -0.569324 -0.566784  0.294746 -0.466516   -0.107834
# Rain          -0.011016 -0.010457 -0.010419  0.017681  0.002100    0.009398
# Rain Rate     -0.005288 -0.008416 -0.008419  0.011692  0.000940    0.005618
# Solar Rad.     0.488092  0.468092  0.465424 -0.434736  0.181901    0.256362
# Solar Energy   0.488093  0.468094  0.465425 -0.434736  0.181903    0.256356
# Hi Solar Rad.  0.499146  0.478674  0.475894 -0.442296  0.188117    0.264502
# Heat D-D      -0.837113 -0.926544 -0.923863  0.553452 -0.607673   -0.232135
# Cool D-D       0.792005  0.755958  0.755215 -0.501349  0.453766    0.082616
# In Temp        0.796647  0.756823  0.753779 -0.369430  0.639092    0.004870
# In Hum        -0.408659 -0.401237 -0.399409  0.602521  0.063749   -0.095911
# In Dew         0.728406  0.682130  0.679572 -0.026114  0.890136   -0.064557
# In Heat        0.799423  0.759106  0.756017 -0.337264  0.674090   -0.006695
# ET             0.202563  0.195075  0.194955 -0.196010  0.057911    0.134804
# Wind Samp      0.104490  0.104440  0.103344  0.022232  0.138790    0.022525
# Wind Tx       -0.003164 -0.002983 -0.002965  0.001619 -0.002530   -0.001167
# ISS Recept     0.103751  0.104484  0.103364  0.014608  0.131796    0.040598
# Arc. Int            NaN       NaN       NaN       NaN       NaN         NaN
# Day sin       -0.450362 -0.435216 -0.434265  0.452333 -0.116473   -0.213365
# Day cos       -0.223757 -0.211761 -0.209511  0.227616 -0.056457   -0.239211
# Year sin       0.096612  0.078910  0.079588  0.212676  0.316065   -0.106014
# Year cos       0.672257  0.647320  0.644029 -0.284088  0.570534   -0.009716
#
#                Wind Dir  Wind Run  Hi Speed    Hi Dir  ...   In Heat  \
# Temp Out       0.244404  0.212836  0.322088  0.246937  ...  0.799423
# Hi Temp        0.231939  0.204288  0.309187  0.234780  ...  0.759106
# Low Temp       0.233991  0.206885  0.311684  0.236768  ...  0.756017
# Out Hum       -0.305096 -0.402432 -0.504793 -0.318324  ... -0.337264
# Dew Pt.        0.025540 -0.120465 -0.085600  0.014211  ...  0.674090
# Wind Speed     0.318082  0.999991  0.918865  0.335477  ... -0.006695
# Wind Dir       1.000000  0.318987  0.433014  0.709830  ...  0.057501
# Wind Run       0.318987  1.000000  0.919271  0.336315  ... -0.006427
# Hi Speed       0.433014  0.919271  1.000000  0.451702  ...  0.082188
# Hi Dir         0.709830  0.336315  0.451702  1.000000  ...  0.063142
# Wind Chill     0.223378  0.168812  0.279750  0.225644  ...  0.760048
# Heat Index     0.226137  0.179907  0.283728  0.227056  ...  0.805677
# THW Index      0.216756  0.141554  0.251906  0.217045  ...  0.808425
# THSW Index     0.101390  0.157498  0.144282  0.110385  ...  0.175071
# Bar           -0.062414 -0.107875 -0.160709 -0.077793  ... -0.572645
# Rain          -0.000158  0.009381  0.004856 -0.001520  ... -0.011175
# Rain Rate      0.000317  0.005593  0.004410 -0.000657  ... -0.006342
# Solar Rad.     0.245895  0.257029  0.327596  0.242228  ...  0.244924
# Solar Energy   0.245891  0.257024  0.327592  0.242224  ...  0.244926
# Hi Solar Rad.  0.246297  0.265182  0.337451  0.242288  ...  0.249918
# Heat D-D      -0.225980 -0.232664 -0.322856 -0.230386  ... -0.658374
# Cool D-D       0.158669  0.083176  0.174861  0.157708  ...  0.652076
# In Temp        0.059021  0.005138  0.096530  0.065843  ...  0.995811
# In Hum        -0.036395 -0.096068 -0.171871 -0.052342  ... -0.585999
# In Dew         0.048910 -0.064340 -0.007761  0.044686  ...  0.841842
# In Heat        0.057501 -0.006427  0.082188  0.063142  ...  1.000000
# ET             0.099921  0.135009  0.159157  0.100267  ...  0.113669
# Wind Samp      0.064045  0.022511  0.057584  0.059237  ...  0.067640
# Wind Tx       -0.001784 -0.001170 -0.001544 -0.001771  ... -0.001643
# ISS Recept     0.078166  0.040599  0.068617  0.075205  ...  0.058462
# Arc. Int            NaN       NaN       NaN       NaN  ...       NaN
# Day sin       -0.125320 -0.213583 -0.239475 -0.124374  ... -0.224688
# Day cos       -0.225141 -0.239824 -0.268736 -0.215857  ...  0.052880
# Year sin      -0.029331 -0.106090 -0.111438 -0.030606  ...  0.139876
# Year cos       0.088961 -0.009435  0.087644  0.096731  ...  0.807866
#
#                      ET  Wind Samp   Wind Tx  ISS Recept  Arc. Int   Day sin  \
# Temp Out       0.202563   0.104490 -0.003164    0.103751       NaN -0.450362
# Hi Temp        0.195075   0.104440 -0.002983    0.104484       NaN -0.435216
# Low Temp       0.194955   0.103344 -0.002965    0.103364       NaN -0.434265
# Out Hum       -0.196010   0.022232  0.001619    0.014608       NaN  0.452333
# Dew Pt.        0.057911   0.138790 -0.002530    0.131796       NaN -0.116473
# Wind Speed     0.134804   0.022525 -0.001167    0.040598       NaN -0.213365
# Wind Dir       0.099921   0.064045 -0.001784    0.078166       NaN -0.125320
# Wind Run       0.135009   0.022511 -0.001170    0.040599       NaN -0.213583
# Hi Speed       0.159157   0.057584 -0.001544    0.068617       NaN -0.239475
# Hi Dir         0.100267   0.059237 -0.001771    0.075205       NaN -0.124374
# Wind Chill     0.191730   0.104849 -0.002903    0.104467       NaN -0.428772
# Heat Index     0.194414   0.104265 -0.003082    0.103100       NaN -0.431029
# THW Index      0.191116   0.105386 -0.003023    0.103806       NaN -0.425218
# THSW Index     0.077476  -0.065368 -0.000671   -0.014784       NaN -0.128383
# Bar           -0.078197  -0.022071  0.001268   -0.027374       NaN  0.137244
# Rain          -0.002627  -0.006947 -0.000038   -0.005245       NaN -0.005348
# Rain Rate     -0.001909  -0.004399 -0.000029   -0.003098       NaN -0.001340
# Solar Rad.     0.306149   0.086105 -0.001101    0.083329       NaN -0.182658
# Solar Energy   0.306148   0.086110 -0.001101    0.083333       NaN -0.182658
# Hi Solar Rad.  0.302676   0.090975 -0.001136    0.087524       NaN -0.194349
# Heat D-D      -0.153873  -0.097547  0.003491   -0.097955       NaN  0.372311
# Cool D-D       0.194688   0.077010 -0.000966    0.076340       NaN -0.383110
# In Temp        0.115823   0.062331 -0.001585    0.052693       NaN -0.223988
# In Hum        -0.095565   0.011020 -0.000490    0.019395       NaN  0.140145
# In Dew         0.079400   0.090319 -0.002224    0.085015       NaN -0.180754
# In Heat        0.113669   0.067640 -0.001643    0.058462       NaN -0.224688
# ET             1.000000   0.040984 -0.000453    0.041356       NaN -0.106640
# Wind Samp      0.040984   1.000000  0.000497    0.992589       NaN -0.094021
# Wind Tx       -0.000453   0.000497  1.000000    0.000449       NaN -0.000055
# ISS Recept     0.041356   0.992589  0.000449    1.000000       NaN -0.093263
# Arc. Int            NaN        NaN       NaN         NaN       NaN       NaN
# Day sin       -0.106640  -0.094021 -0.000055   -0.093263       NaN  1.000000
# Day cos       -0.184101  -0.014359  0.002524   -0.009561       NaN -0.000011
# Year sin      -0.029931   0.012662  0.001520    0.022948       NaN -0.000029
# Year cos       0.119177   0.073062 -0.002007    0.078905       NaN -0.000128
#
#                 Day cos  Year sin  Year cos
# Temp Out      -0.223757  0.096612  0.672257
# Hi Temp       -0.211761  0.078910  0.647320
# Low Temp      -0.209511  0.079588  0.644029
# Out Hum        0.227616  0.212676 -0.284088
# Dew Pt.       -0.056457  0.316065  0.570534
# Wind Speed    -0.239211 -0.106014 -0.009716
# Wind Dir      -0.225141 -0.029331  0.088961
# Wind Run      -0.239824 -0.106090 -0.009435
# Hi Speed      -0.268736 -0.111438  0.087644
# Hi Dir        -0.215857 -0.030606  0.096731
# Wind Chill    -0.203466  0.083236  0.649657
# Heat Index    -0.209969  0.116049  0.674763
# THW Index     -0.202570  0.120407  0.678928
# THSW Index    -0.109582  0.073068  0.163102
# Bar           -0.024019 -0.114147 -0.466687
# Rain           0.000772  0.010649 -0.013392
# Rain Rate     -0.000461  0.010258 -0.005368
# Solar Rad.    -0.641906 -0.068346  0.304478
# Solar Energy  -0.641906 -0.068353  0.304476
# Hi Solar Rad. -0.652197 -0.075221  0.304854
# Heat D-D       0.173328 -0.052621 -0.588833
# Cool D-D      -0.198163  0.096233  0.507773
# In Temp        0.054459  0.117576  0.813631
# In Hum        -0.066412  0.201184 -0.511870
# In Dew         0.017642  0.305494  0.672326
# In Heat        0.052880  0.139876  0.807866
# ET            -0.184101 -0.029931  0.119177
# Wind Samp     -0.014359  0.012662  0.073062
# Wind Tx        0.002524  0.001520 -0.002007
# ISS Recept    -0.009561  0.022948  0.078905
# Arc. Int            NaN       NaN       NaN
# Day sin       -0.000011 -0.000029 -0.000128
# Day cos        1.000000  0.000019  0.000038
# Year sin       0.000019  1.000000 -0.002862
# Year cos       0.000038 -0.002862  1.000000
#
# [35 rows x 35 columns]

# %% [markdown]
# ## Dropeamos las características que no tienen correlación

# %%
df = data.drop(dropped_features, axis = 1)

# %% [markdown]
# ### Normalización de los datos

# %%
df_length = len(df)

train_length = int(df_length*train_perc)
val_length   = int(df_length*(train_perc+val_perc))

train_mean = df.values[:train_length].mean(axis=0)
train_std  = df.values[:train_length].std(axis=0)

df_norm = (df.values - train_mean) / train_std
df_norm = pd.DataFrame(df_norm)

# %% [markdown]
# ### Dividimos los datos

# %%
train_df = df_norm[:train_length-1]
val_df   = df_norm[train_length:val_length-1]
test_df  = df_norm[val_length:]

# %% [markdown]
# ###  Create datasets

# %%
def create_y(df, start, end, length, min_temp):
    y_data = np.arange(end-start)
    
    df_bool = df['Temp Out'][start:end+length] <= min_temp
        
    for i in range(0, end-start):
        y_data[i] = 1 if np.any(df_bool[i:i+length]) else 0

    return y_data

# %%
start = sequence_length*sampling_rate + offset*sampling_rate
end   = train_length + offset*sampling_rate

x_train = train_df
y_train = create_y(df, start, end, length*6, min_temp)

dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    x_train.values,
    y_train,
    sequence_length = sequence_length,
    sampling_rate = sampling_rate,
    shuffle=True,
    batch_size = batch_size
)

# %%
start = train_length + sequence_length*sampling_rate + offset*sampling_rate
end   = val_length + offset*sampling_rate

x_val = val_df
y_val = create_y(df, start, end, length*6, min_temp)

dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val.values,
    y_val,
    sequence_length = sequence_length,
    sampling_rate = sampling_rate,
    shuffle=False,
    batch_size = batch_size
)

# %%
start = val_length + sequence_length*sampling_rate + offset*sampling_rate
x_end = len(test_df) - sequence_length*sampling_rate - offset*sampling_rate

x_test = test_df[:x_end]
y_test = create_y(df, start, df_length, length*6, min_temp)

dataset_test = keras.preprocessing.timeseries_dataset_from_array(
    x_test.values,
    y_test,
    sequence_length = sequence_length,
    sequence_stride = sampling_rate,
    sampling_rate = sampling_rate,
    shuffle=False,
    batch_size = batch_size
)

# %% [markdown]
# ### Creamos el modelo

# %%
for batch in dataset_train.take(1):
    x, y = batch
    
input_shape = x.shape[1], x.shape[2]

# %%
inputs = keras.layers.Input(input_shape)
lstm_layer = keras.layers.LSTM(4, dropout=0.2, recurrent_dropout=0.2, return_sequences=False)(inputs)
output = keras.layers.Dense(1, activation="sigmoid")(lstm_layer)

model = keras.Model(inputs, output)
model.compile(keras.optimizers.Adam(learning_rate), loss=tf.keras.losses.BinaryCrossentropy(from_logits=False))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 90, 23)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 4)                 448
# _________________________________________________________________
# dense (Dense)                (None, 1)                 5
# =================================================================
# Total params: 453
# Trainable params: 453
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Entrenamos el modelo

# %%
path_checkpoint = "model_test_regina2.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=5)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_best_only=True,
)

history = model.fit(dataset_train, epochs = epochs, validation_data=dataset_val, callbacks = [es_callback, modelckpt_callback])
# Out:
# Epoch 1/100
# 1960/1960 [==============================] - 137s 69ms/step - loss: 0.1777 - val_loss: 0.0980
#
# Epoch 00001: val_loss improved from inf to 0.09797, saving model to model_test_regina.h5
# Epoch 2/100
# 1960/1960 [==============================] - 131s 67ms/step - loss: 0.0993 - val_loss: 0.0901
#
# Epoch 00002: val_loss improved from 0.09797 to 0.09006, saving model to model_test_regina.h5
# Epoch 3/100
# 1960/1960 [==============================] - 131s 67ms/step - loss: 0.0931 - val_loss: 0.0871
#
# Epoch 00003: val_loss improved from 0.09006 to 0.08708, saving model to model_test_regina.h5
# Epoch 4/100
# 1960/1960 [==============================] - 131s 67ms/step - loss: 0.0905 - val_loss: 0.0853
#
# Epoch 00004: val_loss improved from 0.08708 to 0.08532, saving model to model_test_regina.h5
# Epoch 5/100
# 1960/1960 [==============================] - 132s 67ms/step - loss: 0.0887 - val_loss: 0.0839
#
# Epoch 00005: val_loss improved from 0.08532 to 0.08391, saving model to model_test_regina.h5
# Epoch 6/100
# 1960/1960 [==============================] - 131s 67ms/step - loss: 0.0876 - val_loss: 0.0824
#
# Epoch 00006: val_loss improved from 0.08391 to 0.08245, saving model to model_test_regina.h5
# Epoch 7/100
# 1960/1960 [==============================] - 129s 66ms/step - loss: 0.0870 - val_loss: 0.0831
#
# Epoch 00007: val_loss did not improve from 0.08245
# Epoch 8/100
# 1960/1960 [==============================] - 130s 66ms/step - loss: 0.0864 - val_loss: 0.0825
#
# Epoch 00008: val_loss did not improve from 0.08245
# Epoch 9/100
# 1960/1960 [==============================] - 132s 67ms/step - loss: 0.0857 - val_loss: 0.0813
#
# Epoch 00009: val_loss improved from 0.08245 to 0.08129, saving model to model_test_regina.h5
# Epoch 10/100
# 1960/1960 [==============================] - 132s 67ms/step - loss: 0.0855 - val_loss: 0.0831
#
# Epoch 00010: val_loss did not improve from 0.08129
# Epoch 11/100
# 1960/1960 [==============================] - 135s 69ms/step - loss: 0.0846 - val_loss: 0.0821
#
# Epoch 00011: val_loss did not improve from 0.08129
# Epoch 12/100
# 1960/1960 [==============================] - 135s 69ms/step - loss: 0.0846 - val_loss: 0.0805
#
# Epoch 00012: val_loss improved from 0.08129 to 0.08047, saving model to model_test_regina.h5
# Epoch 13/100
# 1960/1960 [==============================] - 134s 68ms/step - loss: 0.0839 - val_loss: 0.0812
#
# Epoch 00013: val_loss did not improve from 0.08047
# Epoch 14/100
# 1960/1960 [==============================] - 133s 68ms/step - loss: 0.0837 - val_loss: 0.0794
#
# Epoch 00014: val_loss improved from 0.08047 to 0.07940, saving model to model_test_regina.h5
# Epoch 15/100
# 1960/1960 [==============================] - 135s 69ms/step - loss: 0.0833 - val_loss: 0.0794
#
# Epoch 00015: val_loss improved from 0.07940 to 0.07937, saving model to model_test_regina.h5
# Epoch 16/100
# 1960/1960 [==============================] - 132s 67ms/step - loss: 0.0832 - val_loss: 0.0785
#
# Epoch 00016: val_loss improved from 0.07937 to 0.07850, saving model to model_test_regina.h5
# Epoch 17/100
# 1960/1960 [==============================] - 133s 68ms/step - loss: 0.0827 - val_loss: 0.0781
#
# Epoch 00017: val_loss improved from 0.07850 to 0.07805, saving model to model_test_regina.h5
# Epoch 18/100
# 1960/1960 [==============================] - 136s 69ms/step - loss: 0.0826 - val_loss: 0.0788
#
# Epoch 00018: val_loss did not improve from 0.07805
# Epoch 19/100
# 1960/1960 [==============================] - 136s 69ms/step - loss: 0.0822 - val_loss: 0.0781
#
# Epoch 00019: val_loss did not improve from 0.07805
# Epoch 20/100
# 1960/1960 [==============================] - 137s 70ms/step - loss: 0.0816 - val_loss: 0.0780
#
# Epoch 00020: val_loss improved from 0.07805 to 0.07803, saving model to model_test_regina.h5
# Epoch 21/100
# 1960/1960 [==============================] - 135s 69ms/step - loss: 0.0813 - val_loss: 0.0773
#
# Epoch 00021: val_loss improved from 0.07803 to 0.07732, saving model to model_test_regina.h5
# Epoch 22/100
# 1960/1960 [==============================] - 135s 69ms/step - loss: 0.0813 - val_loss: 0.0779
#
# Epoch 00022: val_loss did not improve from 0.07732
# Epoch 23/100
# 1960/1960 [==============================] - 133s 68ms/step - loss: 0.0811 - val_loss: 0.0801
#
# Epoch 00023: val_loss did not improve from 0.07732
# Epoch 24/100
# 1960/1960 [==============================] - 134s 69ms/step - loss: 0.0811 - val_loss: 0.0792
#
# Epoch 00024: val_loss did not improve from 0.07732
# Epoch 25/100
# 1494/1960 [=====================>........] - ETA: 30s - loss: 0.0805

# %%
plt.rcParams['figure.figsize'] = [6, 4]

def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.ylim(0.05, 0.18)
    plt.legend()
    plt.show()

visualize_loss(history, "Training and Validation Loss")

# %% [markdown]
# ### Mostramos los resultados

# %%
i = start

print(data.index[start])

test_real_y = np.zeros(0)
test_pred_y = np.zeros(0)
fechas  = np.zeros(0, dtype='datetime64')

plt.rcParams['figure.figsize'] = [15, 5]

test_size  = tf.data.experimental.cardinality(dataset_test).numpy()

for batch in dataset_test.take(test_size):
    x, y = batch
    y_pred = model.predict(x)
    
    if ()
    
    b_size = x.shape[0]
    
    test_real_y  = np.concatenate((test_real_y, y))
    test_pred_y  = np.concatenate((test_pred_y, np.squeeze(y_pred)))
    fechas  = np.concatenate((fechas, np.squeeze(np.array(data.index)[i:i+b_size])))
    
    fig, ax = plt.subplots()
    
    ax.plot(data.index[i:i+b_size], y[0:b_size], c='r', label="Test Data")
    ax.plot(data.index[i:i+b_size], (y_pred[0:b_size]),c='g', label="Prediction")
    
    i += b_size
    
    plt.ylim(0, 1.1)
    plt.legend()
    plt.show()
    
test_size = (test_size-1)*batch_size + b_size

# %%
train_size = tf.data.experimental.cardinality(dataset_train).numpy()
val_size   = tf.data.experimental.cardinality(dataset_val).numpy()

# %%
train_real_y = np.zeros(0)
train_pred_y = np.zeros(0)

for batch in dataset_train.take(train_size):
    x, y = batch
    y_pred = model.predict(x)

    last_batch_size = x.shape[0]
    
    train_real_y  = np.concatenate((train_real_y, y))
    train_pred_y  = np.concatenate((train_pred_y, np.squeeze(y_pred)))
    
train_size = (train_size-1)*batch_size + last_batch_size

# %%
val_real_y = np.zeros(0)
val_pred_y = np.zeros(0)

for batch in dataset_val.take(val_size):
    x, y = batch
    y_pred = model.predict(x)
    
    last_batch_size = x.shape[0]

    val_real_y  = np.concatenate((val_real_y, y))
    val_pred_y  = np.concatenate((val_pred_y, np.squeeze(y_pred)))

val_size = (val_size-1)*batch_size + last_batch_size

# %%
conf_matrix_train = confusion_matrix(train_real_y, np.around(train_pred_y))
conf_matrix_val   = confusion_matrix(val_real_y, np.around(val_pred_y))
conf_matrix_test  = confusion_matrix(test_real_y, np.around(test_pred_y)) 

ConfusionMatrixDisplay(conf_matrix_test, display_labels=['No Heló', 'Heló']).plot()

plt.show()

# %%
tn_train, fp_train, fn_train, tp_train = conf_matrix_train.ravel()
tn_val, fp_val, fn_val, tp_val         = conf_matrix_val.ravel()
tn_test, fp_test, fn_test, tp_test     = conf_matrix_test.ravel()

def accuracy(tn, fp, fn, tp): return (tp+tn)/(tp+tn+fp+fn)
def precision(tp, fp): return tp/(tp+fp)
def recall(tp, fn): return tp/(tp+fn)
def f1(tp, fp, fn): return (2*tp)/(2*tp+fp+fn)

stats = pd.DataFrame({'Dataset':   ['train', 'val', 'test'],
                      'Size':      [train_size, val_size, test_size],
                      'Accuracy':  [accuracy(tn_train, fp_train, fn_train, tp_train), accuracy(tn_val, fp_val, fn_val, tp_val), accuracy(tn_test, fp_test, fn_test, tp_test)],
                      'Precision': [precision(tp_train, fp_train), precision(tp_val, fp_val), precision(tp_test, fp_test)],
                      'Recall':    [recall(tp_train, fn_train), recall(tp_val, fn_val), recall(tp_test, fn_test)],
                      'F1':        [f1(tp_train, fp_train, fn_train), f1(tp_val, fp_val, fn_val), f1(tp_test, fp_test, fn_test)]})

stats.style.hide_index()

# %%
fechas = pd.to_datetime(fechas)

indexes = np.intersect1d(np.argwhere(test_real_y), np.argwhere((fechas.hour >= 20) & (fechas.hour <= 23)))
metrica_noche = test_pred_y[indexes]
fechas_noche  = fechas[indexes]

indexes = np.intersect1d(np.argwhere(test_real_y == 0), np.argwhere((fechas.hour >= 20) & (fechas.hour <= 23)))
falsos_positivos = test_pred_y[indexes]
fechas_positivos = fechas[indexes]

indexes = np.squeeze(np.argwhere((fechas_noche.hour == 23) & (fechas_noche.minute == 50)))
metrica_split = np.split(metrica_noche, indexes)

indexes = np.squeeze(np.argwhere((fechas_positivos.hour == 23) & (fechas_positivos.minute == 50)))
falsos_split = np.split(falsos_positivos, indexes)

print('METRICAS')
print('Estadísticas teniendo en cuenta el período de 20hs a 00hs')
print()
print('Dataset Test:')
print('Cantidad de noches predecidas / Cantidad de noches que heló: ', sum(np.any(x >= 0.5) for x in metrica_split), '/', len(metrica_split))
print('Cantidad de noches con falsos positivos: ', sum(np.any(x >= 0.5) for x in falsos_split), '/', len(falsos_split))
print()

metrica_noche = metrica_noche[(fechas_noche.month == 8) | (fechas_noche.month == 9) | (fechas_noche.month == 10)]
fechas_noche = fechas_noche[(fechas_noche.month == 8) | (fechas_noche.month == 9) | (fechas_noche.month == 10)]
falsos_positivos = falsos_positivos[(fechas_positivos.month == 8) | (fechas_positivos.month == 9) | (fechas_positivos.month == 10)]
fechas_positivos = fechas_positivos[(fechas_positivos.month == 8) | (fechas_positivos.month == 9) | (fechas_positivos.month == 10)]

indexes = np.squeeze(np.argwhere((fechas_noche.hour == 23) & (fechas_noche.minute == 50)))
metrica_split = np.split(metrica_noche, indexes)
indexes = np.squeeze(np.argwhere((fechas_positivos.hour == 23) & (fechas_positivos.minute == 50)))
falsos_split = np.split(falsos_positivos, indexes)

print('Dataset Test (meses 8, 9 y 10):')
print('Cantidad de noches predecidas / Cantidad de noches que heló: ', sum(np.any(x >= 0.5) for x in metrica_split), '/', len(metrica_split))
print('Cantidad de noches con falsos positivos: ', sum(np.any(x >= 0.5) for x in falsos_split), '/', len(falsos_split))
